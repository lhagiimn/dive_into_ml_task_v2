# %% [markdown]
# # [Problem 1] Creating random numbers

# %%
import numpy as np

# %%
np.random.seed(42)

mean = (-3, 0)
covariance_matrix = np.asarray([[1.0, 0.8], [0.8, 1.0]])
arr = np.random.multivariate_normal(mean, covariance_matrix, size=500)

# %%
arr.shape
# Out:
# (500, 2)

# %% [markdown]
# # [Problem 2] Visualization by scatter plot

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(arr[:, 0], arr[:, 1])
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# # [Problem 3] Visualization by histogram

# %%
plt.hist(arr, bins=100)
plt.xlim(-5, 2)
plt.show()

# %%
plt.hist(arr[:, 0], bins=100)
plt.xlim(-5, 2)
# plt.xlabel("x")
# plt.ylabel("frequency")
plt.show()

# %%
plt.hist(arr[:, 1], bins=100)
plt.xlim(-5, 2)
# plt.xlabel("x")
# plt.ylabel("frequency")
plt.show()

# %% [markdown]
# # [Problem 4] Addition of data

# %%
mean = (-3, 0)
covariance_matrix = np.asarray([[1.0, 0.8], [0.8, 1.0]])
arr1 = np.random.multivariate_normal(mean, covariance_matrix, size=500)

# %%
mean = (0, -3)
covariance_matrix = np.asarray([[1.0, 0.8], [0.8, 1.0]])
arr2 = np.random.multivariate_normal(mean, covariance_matrix, size=500)

# %%
plt.scatter(arr1[:, 0], arr1[:, 1], label="0")
plt.scatter(arr2[:, 0], arr2[:, 1], label="1")
plt.legend()
plt.show()

# %% [markdown]
# # [Problem 5] Data combination

# %%
arr_full = np.concatenate((arr1, arr2), axis=0)
arr_full.shape
# Out:
# (1000, 2)

# %%
arr_full = np.vstack((arr1, arr2))
arr_full.shape
# Out:
# (1000, 2)

# %% [markdown]
# # [Problem 6] Labeling

# %%
label = np.zeros((500, 1))
label.shape
# Out:
# (500, 1)

# %%
arr1 = np.concatenate((arr1, label), axis=1)
arr1.shape
# Out:
# (500, 3)

# %%
label1 = np.ones((500, 1))
label1.shape
# Out:
# (500, 1)

# %%
arr2 = np.concatenate((arr2, label1), axis=1)
arr2.shape
# Out:
# (500, 3)

# %%
arr_full = np.concatenate((arr1, arr2), axis=0)
arr_full.shape
# Out:
# (1000, 3)

# %%
arr_full[:10, :]
# Out:
# array([[-2.31376883,  0.59482954,  0.        ],
#        [-2.15085847,  0.65436956,  0.        ],
#        [-1.27100879,  1.86389   ,  0.        ],
#        [-2.7427575 , -0.25952973,  0.        ],
#        [-3.92190107, -0.32892964,  0.        ],
#        [-1.23374005,  1.28387044,  0.        ],
#        [-1.97310404,  0.43244904,  0.        ],
#        [-3.72561572, -0.84820214,  0.        ],
#        [-2.11538227, -0.38273611,  0.        ],
#        [-3.21092256, -0.99469839,  0.        ]])

# %%
arr_full[-10:, :]
# Out:
# array([[-1.8114485 , -3.77383274,  1.        ],
#        [-2.63502357, -6.34558359,  1.        ],
#        [ 0.42799931, -3.88883553,  1.        ],
#        [-0.35140721, -3.69811952,  1.        ],
#        [-1.57978614, -5.06969566,  1.        ],
#        [ 1.75152642, -1.54652694,  1.        ],
#        [ 1.63659375, -0.88836924,  1.        ],
#        [ 1.95011072, -1.03189113,  1.        ],
#        [ 2.07247243, -1.13010169,  1.        ],
#        [-1.67309229, -4.44499853,  1.        ]])
